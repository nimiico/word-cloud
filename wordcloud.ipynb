# %%
text = open('data/movies.txt').read()

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from wordcloud import STOPWORDS

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
wordcloud = WordCloud(
    background_color='white',
    max_words=100,
    max_font_size=50,
    stopwords=STOPWORDS.union({'love'})
).generate(text)

# %%
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wordcloud.to_file('wordcloud.png')

# %%
from collections import Counter
Counter(text.split()).most_common()
# Out:
# [('The', 10082),
#  ('of', 4832),
#  ('the', 4480),
#  ('and', 1563),
#  ('in', 1388),
#  ('A', 1235),
#  ('a', 1004),
#  ('to', 920),
#  ('Man', 638),
#  ('Love', 634),
#  ('My', 532),
#  ('for', 486),
#  ('I', 477),
#  ('&', 455),
#  ('on', 445),
#  ('Story', 392),
#  ('Night', 382),
#  ('Life', 374),
#  ('You', 346),
#  ('Last', 345),
#  ('2', 327),
#  ('Me', 325),
#  ('Is', 310),
#  ('In', 303),
#  ('from', 296),
#  ('Girl', 296),
#  ('with', 290),
#  ('at', 279),
#  ('Dead', 278),
#  ('One', 269),
#  ('Day', 264),
#  ('-', 260),
#  ('Time', 258),
#  ('All', 253),
#  ('Black', 251),
#  ('Movie', 245),
#  ('House', 243),
#  ('World', 243),
#  ('Little', 236),
#  ('Death', 233),
#  ('Christmas', 220),
#  ('American', 207),
#  ('Big', 202),
#  ('Dark', 200),
#  ('New', 198),
#  ('City', 195),
#  ('Blood', 195),
#  ('It', 194),
#  ('No', 188),
#  ('White', 181),
#  ('War', 181),
#  ('Men', 176),
#  ('Days', 170),
#  ('King', 167),
#  ('Woman', 165),
#  ('2:', 164),
#  ('Lost', 163),
#  ('Out', 163),
#  ('Red', 162),
#  ('Two', 158),
#  ('Who', 156),
#  ('Blue', 155),
#  ('We', 153),
#  ('Mr.', 151),
#  ('Your', 150),
#  ('II', 149),
#  ('Summer', 148),
#  ('That', 148),
#  ('Wild', 146),
#  ('Three', 145),
#  ('La', 143),
#  ('Be', 139),
#  ('Good', 139),
#  ('Great', 139),
#  ('Home', 138),
#  ('An', 137),
#  ('Up', 137),
#  ('Secret', 137),
#  ('Not', 137),
#  ('On', 134),
#  ('Girls', 133),
#  ('Bad', 133),
#  ('Heart', 132),
#  ('To', 131),
#  ("Don't", 130),
#  ('Boy', 127),
#  ('Way', 125),
#  ('High', 125),
#  ('Street', 124),
#  ('Back', 124),
#  ('Die', 123),
#  ('Island', 122),
#  ('Legend', 122),
#  ('3', 122),
#  ('Lady', 122),
#  ('How', 120),
#  ('Live', 119),
#  ('What', 119),
#  ('Return', 119),
#  ('Are', 119),
#  ('This', 118),
#  ('First', 116),
#  ('Road', 115),
#  ('For', 114),
#  ('About', 114),
#  ('Part', 113),
#  ('by', 113),
#  ('de', 112),
#  ('Moon', 111),
#  ('People', 110),
#  ('Star', 109),
#  ('Family', 109),
#  ('Kill', 108),
#  ('Sea', 107),
#  ('Young', 107),
#  ('Women', 107),
#  ('Ghost', 107),
#  ('End', 106),
#  ('Dragon', 104),
#  ('When', 102),
#  ('Down', 102),
#  ('Go', 102),
#  ('Land', 102),
#  ('Of', 101),
#  ('Boys', 100),
#  ('Killer', 100),
#  ('Year', 98),
#  ('Like', 98),
#  ('Under', 97),
#  ('Fire', 97),
#  ('Our', 97),
#  ('Game', 96),
#  ('Hell', 96),
#  ('God', 95),
#  ('Dog', 94),
#  ('Murder', 93),
#  ('Beyond', 92),
#  ('Living', 92),
#  ('or', 92),
#  ('Earth', 92),
#  ('From', 91),
#  ('After', 91),
#  ('Adventures', 90),
#  ('Son', 90),
#  ('Space', 90),
#  ('Journey', 89),
#  ('Dream', 89),
#  ('Tale', 88),
#  ('Monster', 88),
#  ('Heaven', 87),
#  ('Kiss', 86),
#  ('Sun', 85),
#  ('Party', 85),
#  ('Never', 85),
#  ('Room', 84),
#  ("It's", 83),
#  ('II:', 82),
#  ('Perfect', 82),
#  ('Final', 81),
#  ('Old', 80),
#  ('Devil', 80),
#  ('Us', 80),
#  ('River', 80),
#  ('Evil', 80),
#  ('Her', 80),
#  ('vs.', 80),
#  ('Will', 80),
#  ('Battle', 80),
#  ('Fear', 79),
#  ('America', 79),
#  ('Without', 79),
#  ('Town', 79),
#  ('Four', 78),
#  ('Before', 78),
#  ('Wedding', 78),
#  ('Long', 78),
#  ('Green', 77),
#  ('Dr.', 77),
#  ('Children', 76),
#  ('Do', 76),
#  ('Best', 76),
#  ('Seven', 76),
#  ('Baby', 76),
#  ('Am', 76),
#  ('Come', 75),
#  ('Just', 74),
#  ('Water', 74),
#  ('Le', 74),
#  ('Beautiful', 73),
#  ('Paris', 73),
#  ('Run', 73),
#  ('Magic', 73),
#  ('Other', 73),
#  ('Case', 73),
#  ('Get', 72),
#  ('Angels', 72),
#  ('Happy', 72),
#  ('His', 72),
#  ('School', 72),
#  ('Eyes', 72),
#  ('They', 71),
#  ('Sweet', 71),
#  ("I'm", 70),
#  ('Here', 68),
#  ('Song', 68),
#  ('Queen', 67),
#  ('West', 67),
#  ('Kid', 66),
#  ('York', 66),
#  ('Film', 66),
#  ('Miss', 66),
#  ('Angel', 65),
#  ('Eye', 65),
#  ('Gun', 65),
#  ('True', 65),
#  ('Jack', 65),
#  ('Snow', 65),
#  ('Midnight', 65),
#  ('3:', 65),
#  ('El', 65),
#  ('Once', 64),
#  ('Sky', 64),
#  ('Cat', 64),
#  ('Sex', 64),
#  ('Five', 64),
#  ('Princess', 63),
#  ('Hero', 63),
#  ('Was', 63),
#  ('Years', 63),
#  ('an', 62),
#  ('Rock', 62),
#  ('Crazy', 62),
#  ('Ice', 62),
#  ('Light', 62),
#  ('Can', 62),
#  ('Country', 61),
#  ('Paradise', 61),
#  ('Goes', 61),
#  ('Iron', 61),
#  ('And', 61),
#  ('Bride', 60),
#  ('Fall', 60),
#  ('Over', 60),
#  ('Wind', 60),
#  ('Adventure', 59),
#  ('Wolf', 59),
#  ('Too', 59),
#  ('Take', 59),
#  ('Body', 58),
#  ('Wife', 58),
#  ('Brothers', 58),
#  ('Human', 58),
#  ('Only', 58),
#  ('Hard', 58),
#  ('Shadow', 58),
#  ('Call', 58),
#  ('Darkness', 58),
#  ('Planet', 58),
#  ('III', 57),
#  ('If', 57),
#  ('Vampire', 57),
#  ('Tales', 57),
#  ('Another', 57),
#  ('Hot', 57),
#  ('Terror', 57),
#  ('Into', 57),
#  ('Charlie', 57),
#  ('Side', 56),
#  ('Dreams', 56),
#  ('Gold', 56),
#  ('Mystery', 56),
#  ('Next', 56),
#  ('Golden', 56),
#  ('Special', 56),
#  ('Father', 55),
#  ('Dawn', 55),
#  ('Book', 55),
#  ('Beast', 55),
#  ('Dance', 55),
#  ('Revenge', 55),
#  ('Master', 55),
#  ('Money', 54),
#  ('Hollywood', 54),
#  ('With', 54),
#  ('Mad', 54),
#  ('Strange', 54),
#  ('Club', 54),
#  ('Times', 54),
#  ('Prince', 54),
#  ('Lives', 54),
#  ('Deep', 54),
#  ('Where', 54),
#  ('Train', 53),
#  ('Les', 53),
#  ('Face', 53),
#  ('Park', 53),
#  ('North', 53),
#  ('Doctor', 53),
#  ('Comedy', 53),
#  ('Dirty', 52),
#  ('So', 52),
#  ('Away', 52),
#  ('Mountain', 52),
#  ('Deadly', 52),
#  ('Truth', 52),
#  ('John', 52),
#  ('Again', 52),
#  ('Zero', 52),
#  ('Things', 51),
#  ('Born', 51),
#  ('Blues', 51),
#  ('Cold', 51),
#  ('Have', 51),
#  ('Rise', 51),
#  ('Escape', 50),
#  ('Double', 50),
#  ('Meet', 50),
#  ("Devil's", 50),
#  ('Stranger', 50),
#  ('Dangerous', 49),
#  ('Cop', 49),
#  ('Beach', 49),
#  ('Diary', 49),
#  ('Mother', 49),
#  ('Lake', 49),
#  ('Curse', 49),
#  ('Child', 49),
#  ('Flight', 49),
#  ('Stars', 48),
#  ('Friends', 48),
#  ('Santa', 48),
#  ('Naked', 48),
#  ('Killing', 48),
#  ('Crime', 48),
#  ('Private', 48),
#  ('Hotel', 48),
#  ('Winter', 48),
#  ('Art', 48),
#  ('She', 48),
#  ('Silent', 48),
#  ('Now', 47),
#  ('Nightmare', 47),
#  ('Beauty', 47),
#  ('Alone', 47),
#  ('Hunter', 47),
#  ('Play', 47),
#  ('Daughter', 47),
#  ('Captain', 47),
#  ('7', 47),
#  ('Lucky', 47),
#  ('Free', 46),
#  ('Trouble', 46),
#  ('Hill', 46),
#  ('Garden', 46),
#  ('Holiday', 46),
#  ('Edge', 46),
#  ('III:', 45),
#  ('Thing', 45),
#  ('Inside', 45),
#  ('Place', 45),
#  ('Joe', 45),
#  ('Behind', 45),
#  ('Broken', 44),
#  ('Affair', 44),
#  ('Age', 44),
#  ('There', 44),
#  ('Flesh', 44),
#  ('Nothing', 44),
#  ('Second', 44),
#  ('Law', 44),
#  ('la', 44),
#  ('Shadows', 44),
#  ('Phantom', 44),
#  ('Glory', 44),
#  ('At', 44),
#  ('Point', 44),
#  ('Tom', 43),
#  ('Forever', 43),
#  ('Rain', 43),
#  ('Super', 43),
#  ('Welcome', 43),
#  ('Spy', 43),
#  ('Valley', 43),
#  ('Music', 43),
#  ('Rose', 43),
#  ('Attack', 43),
#  ('Kids', 42),
#  ('Bill', 42),
#  ('Dogs', 42),
#  ('Machine', 42),
#  ('Blind', 42),
#  ('Fury', 42),
#  ('Invisible', 42),
#  ('Johnny', 41),
#  ('Castle', 41),
#  ('George', 41),
#  ('Made', 41),
#  ('Stone', 41),
#  ('Small', 41),
#  ('Alien', 41),
#  ('Tomorrow', 41),
#  ('Why', 41),
#  ('Camp', 41),
#  ('Il', 41),
#  ('Line', 40),
#  ('Upon', 40),
#  ('Were', 40),
#  ('Walk', 40),
#  ('X', 40),
#  ('Tree', 40),
#  ('Force', 40),
#  ('Thief', 40),
#  ('Witch', 40),
#  ('Alice', 40),
#  ('Spring', 40),
#  ('Bridge', 40),
#  ('Harry', 40),
#  ('London', 40),
#  ('Ride', 40),
#  ('Flying', 40),
#  ('Soldier', 40),
#  ('Zombie', 40),
#  ('Power', 39),
#  ('Wars', 39),
#  ('Jungle', 39),
#  ('Air', 39),
#  ('Still', 39),
#  ('Ninja', 39),
#  ('Alive', 39),
#  ('Horse', 39),
#  ('Brother', 38),
#  ('as', 38),
#  ('Lovers', 38),
#  ('Project', 38),
#  ('Mars', 38),
#  ('As', 38),
#  ('Let', 38),
#  ('Ball', 38),
#  ('Treasure', 37),
#  ('Glass', 37),
#  ('Frankenstein', 37),
#  ('Name', 37),
#  ('Justice', 37),
#  ('Nights', 37),
#  ('is', 37),
#  ('Guy', 37),
#  ('Louis', 37),
#  ('Skin', 37),
#  ('Right', 37),
#  ('Breaking', 37),
#  ('Soul', 37),
#  ('Tokyo', 37),
#  ('Going', 37),
#  ('Samurai', 37),
#  ('See', 37),
#  ('Enemy', 37),
#  ('Massacre', 37),
#  ('1', 37),
#  ('Mine', 37),
#  ('Door', 37),
#  ('13', 36),
#  ('Vengeance', 36),
#  ('Show', 36),
#  ('Miracle', 36),
#  ('Company', 36),
#  ('Silence', 36),
#  ('Sword', 36),
#  ('Secrets', 36),
#  ('Kind', 36),
#  ('Know', 36),
#  ('Texas', 36),
#  ('Hearts', 36),
#  ('Head', 36),
#  ('China', 36),
#  ('History', 36),
#  ('Ten', 36),
#  ('Mary', 35),
#  ('Wrong', 35),
#  ('Express', 35),
#  ('Something', 35),
#  ("Man's", 35),
#  ('Hands', 35),
#  ('Trip', 35),
#  ('Stories', 35),
#  ('Very', 35),
#  ('Comes', 35),
#  ('Bloody', 35),
#  ('Storm', 35),
#  ('State', 35),
#  ('Forest', 35),
#  ('Through', 35),
#  ('More', 35),
#  ('Kingdom', 35),
#  ('By', 35),
#  ('Desert', 34),
#  ('Lies', 34),
#  ('Fish', 34),
#  ('Came', 34),
#  ('Six', 34),
#  ('Haunted', 34),
#  ('Hour', 34),
#  ('Fu', 34),
#  ('National', 34),
#  ('Mission', 34),
#  ('Cry', 34),
#  ('Most', 34),
#  ('Friday', 33),
#  ("You're", 33),
#  ('Heroes', 33),
#  ('Detective', 33),
#  ('Open', 33),
#  ('Being', 33),
#  ('Romance', 33),
#  ('Between', 33),
#  ('Freedom', 33),
#  ('Business', 33),
#  ('Called', 33),
#  ('Grand', 33),
#  ('Voyage', 33),
#  ('Sister', 33),
#  ('Warrior', 33),
#  ('Against', 33),
#  ('Confessions', 33),
#  ('Shark', 33),
#  ('St.', 32),
#  ('Letter', 32),
#  ('Broadway', 32),
#  ('Mrs.', 32),
#  ('Season', 32),
#  ('Giant', 32),
#  ('Grace', 32),
#  ('Sleep', 32),
#  ('Future', 32),
#  ('Work', 32),
#  ('Fight', 32),
#  ('Mind', 32),
#  ('Unknown', 32),
#  ('Tell', 32),
#  ('Spirit', 32),
#  ('Dear', 31),
#  ('Faces', 31),
#  ('Police', 31),
#  ('Michael', 31),
#  ('Band', 31),
#  ('Top', 31),
#  ('Gang', 31),
#  ('Holy', 31),
#  ('Hand', 31),
#  ('Real', 31),
#  ('Wall', 31),
#  ('Horror', 31),
#  ('Dracula', 31),
#  ('Hunt', 31),
#  ('Bang', 31),
#  ('Friend', 31),
#  ('Hope', 31),
#  ('Million', 31),
#  ('Goodbye', 31),
#  ('Look', 31),
#  ('Making', 31),
#  ('Dust', 31),
#  ('Coming', 31),
#  ('Kung', 31),
#  ('David', 31),
#  ('Heat', 30),
#  ('Race', 30),
#  ('Circle', 30),
#  ('Far', 30),
#  ('Rising', 30),
#  ('Saint', 30),
#  ('Want', 30),
#  ('Pretty', 30),
#  ('Brain', 30),
#  ('Sisters', 30),
#  ('Gone', 30),
#  ('East', 30),
#  ('Off', 30),
#  ('Pink', 30),
#  ('Class', 30),
#  ('Left', 30),
#  ('Brown', 30),
#  ('Full', 30),
#  ('Better', 30),
#  ('Stand', 30),
#  ('Forbidden', 30),
#  ("Can't", 30),
#  ('Easy', 30),
#  ('Sunday', 30),
#  ('Trail', 30),
#  ('Fast', 30),
#  ('Games', 30),
#  ('Tiger', 30),
#  ('Chance', 30),
#  ('Perry', 30),
#  ('Central', 29),
#  ('Happiness', 29),
#  ('Frank', 29),
#  ('Weekend', 29),
#  ('Bear', 29),
#  ('Funny', 29),
#  ('Cool', 29),
#  ('Sound', 29),
#  ('Henry', 29),
#  ('Quiet', 29),
#  ('Box', 29),
#  ('Chapter', 29),
#  ('Gods', 29),
#  ('Must', 29),
#  ('O', 29),
#  ('Carry', 29),
#  ('Make', 28),
#  ('Don', 28),
#  ('Kings', 28),
#  ('Than', 28),
#  ('Guys', 28),
#  ('Search', 28),
#  ('He', 28),
#  ('Passion', 28),
#  ('Third', 28),
#  ('Own', 28),
#  ('Late', 28),
#  ('May', 28),
#  ('10', 28),
#  ('Jim', 28),
#  ('Morning', 28),
#  ('Code', 28),
#  ('Always', 28),
#  ('Missing', 28),
#  ('Hours', 28),
#  ('Across', 27),
#  ('Lord', 27),
#  ('Talk', 27),
#  ('Picture', 27),
#  ('Sleeping', 27),
#  ('But', 27),
#  ('Army', 27),
#  ('Action', 27),
#  ('Short', 27),
#  ('Century', 27),
#  ('Flower', 27),
#  ('Shot', 27),
#  ('Saw', 27),
#  ('Everything', 27),
#  ('Burning', 27),
#  ('Touch', 27),
#  ('Has', 27),
#  ('Guns', 27),
#  ('Vacation', 27),
#  ('4', 27),
#  ('4:', 27),
#  ('Max', 27),
#  ('Running', 27),
#  ('Teenage', 27),
#  ('Brave', 27),
#  ('Bullet', 27),
#  ('Waiting', 26),
#  ('Walking', 26),
#  ('Billy', 26),
#  ('Zone', 26),
#  ('Eat', 26),
#  ('Warriors', 26),
#  ('Demon', 26),
#  ('Hills', 26),
#  ('Got', 26),
#  ('Butterfly', 26),
#  ('Manhattan', 26),
#  ('Robin', 26),
#  ('Quest', 26),
#  ('Remember', 26),
#  ('Bird', 26),
#  ('12', 26),
#  ('Apocalypse', 26),
#  ('Returns', 26),
#  ('Ever', 26),
#  ('Wish', 26),
#  ('Thousand', 26),
#  ('9', 26),
#  ('Past', 26),
#  ('Their', 26),
#  ('Sherlock', 26),
#  ('Worlds', 26),
#  ('Eagle', 26),
#  ('5', 26),
#  ('Killed', 26),
#  ('Barbie', 26),
#  ('Youth', 26),
#  ('Scooby-Doo!', 26),
#  ('Richard', 25),
#  ('South', 25),
#  ('Knight', 25),
#  ('Nine', 25),
#  ('Grave', 25),
#  ('Color', 25),
#  ('Jane', 25),
#  ('Fever', 25),
#  ('James', 25),
#  ('Some', 25),
#  ('Cinderella', 25),
#  ('Looking', 25),
#  ('Dancing', 25),
#  ('Empire', 25),
#  ('Ghosts', 25),
#  ('Joy', 25),
#  ('Beginning', 25),
#  ('5:', 25),
#  ('Ring', 25),
#  ("Let's", 25),
#  ('Honor', 25),
#  ('Lights', 25),
#  ('Berlin', 25),
#  ('Date', 25),
#  ('Souls', 25),
#  ('Lonely', 25),
#  ('Wanted', 25),
#  ('Them', 25),
#  ('Magnificent', 25),
#  ('Jesus', 25),
#  ('e', 25),
#  ('Mason:', 25),
#  ('Takes', 24),
#  ('Hood', 24),
#  ('Virgin', 24),
#  ('Batman', 24),
#  ('Madness', 24),
#  ('Above', 24),
#  ("I'll", 24),
#  ('Jimmy', 24),
#  ('Married', 24),
#  ('Hate', 24),
#  ('Stop', 24),
#  ('Every', 24),
#  ('100', 24),
#  ('Anna', 24),
#  ('Steel', 24),
#  ('Luck', 24),
#  ('Godzilla', 24),
#  ('Almost', 24),
#  ('Greatest', 24),
#  ('Strangers', 24),
#  ('Among', 24),
#  ('Meets', 24),
#  ('Within', 24),
#  ('Act', 24),
#  ('Circus', 24),
#  ('Hidden', 24),
#  ('Rage', 24),
#  ('Minutes', 24),
#  ('Tears', 24),
#  ('Gangster', 24),
#  ('Zombies', 24),
#  ('Shaolin', 24),
#  ('Chronicles', 24),
#  ('Loves', 23),
#  ('Killers', 23),
#  ('8', 23),
#  ('Getting', 23),
#  ('Jones', 23),
#  ('Wonderful', 23),
#  ('Eve', 23),
#  ('Mark', 23),
#  ('Around', 23),
#  ('Fly', 23),
#  ('Trap', 23),
#  ('Wonderland', 23),
#  ('Agent', 23),
#  ('Thunder', 23),
#  ('Portrait', 23),
#  ('Nowhere', 23),
#  ('Hercules', 23),
#  ('Twilight', 23),
#  ('Blonde', 23),
#  ('Honey', 23),
#  ('Snake', 23),
#  ('Holmes', 23),
#  ('du', 23),
#  ('Change', 23),
#  ('Nation', 23),
#  ('Ones', 23),
#  ('di', 23),
#  ('Pirates', 23),
#  ('Legacy', 23),
#  ('Wings', 22),
#  ('August', 22),
#  ('Brooklyn', 22),
#  ('Target', 22),
#  ('Amazing', 22),
#  ("What's", 22),
#  ('Lion', 22),
#  ('Mask', 22),
#  ('Happened', 22),
#  ('Falls', 22),
#  ('Gate', 22),
#  ('Wives', 22),
#  ('Seventh', 22),
#  ('Did', 22),
#  ('Number', 22),
#  ('Rio', 22),
#  ('Sam', 22),
#  ('Loved', 22),
#  ('Sunshine', 22),
#  ('Cut', 22),
#  ('Flowers', 22),
#  ('Fat', 22),
#  ('Royal', 22),
#  ('Marriage', 22),
#  ('De', 22),
#  ('VeggieTales:', 22),
#  ('Falling', 21),
#  ('Nobody', 21),
#  ('Generation', 21),
#  ('Eden', 21),
#  ('Yellow', 21),
#  ('Lover', 21),
#  ('Could', 21),
#  ('Murders', 21),
#  ('Blade', 21),
#  ('Wolves', 21),
#  ('San', 21),
#  ('Eddie', 21),
#  ('Operation', 21),
#  ('Promise', 21),
#  ('Cross', 21),
#  ('Pride', 21),
#  ('Lone', 21),
#  ('Conspiracy', 21),
#  ('Moment', 21),
#  ('Carol', 21),
#  ('April', 21),
#  ('Werewolf', 21),
#  ('Team', 21),
#  ('Revolution', 21),
#  ('Eight', 21),
#  ('Turn', 21),
#  ('Streets', 21),
#  ('Price', 21),
#  ('Halloween', 21),
#  ('Tall', 21),
#  ('Autumn', 21),
#  ("Who's", 21),
#  ('Say', 21),
#  ('Monsters', 21),
#  ('Paul', 21),
#  ('Dinner', 21),
#  ('Rules', 21),
#  ('Assassin', 21),
#  ('Silver', 21),
#  ('Dying', 21),
#  ('Italian', 21),
#  ('Car', 21),
#  ('Incident', 21),
#  ('United', 21),
#  ('Frozen', 21),
#  ('Vegas', 20),
#  ('Shanghai', 20),
#  ('Bed', 20),
#  ('Hall', 20),
#  ('Belle', 20),
#  ('Moonlight', 20),
#  ('Sin', 20),
#  ('6', 20),
#  ('Ballad', 20),
#  ('Beat', 20),
#  ('Thieves', 20),
#  ('Highway', 20),
#  ('Rescue', 20),
#  ('Below', 20),
#  ('Chasing', 20),
#  ('Half', 20),
#  ('September', 20),
#  ('Fist', 20),
#  ('Station', 20),
#  ('Voice', 20),
#  ('Fantastic', 20),
#  ('Watch', 20),
#  ('Straight', 20),
#  ('Shoot', 20),
#  ('Job', 20),
#  ('Animal', 20),
#  ('Merry', 20),
#  ('Opera', 20),
#  ('Finding', 20),
#  ('Experiment', 20),
#  ('Babylon', 20),
#  ('No.', 20),
#  ('Forgotten', 20),
#  ('Break', 20),
#  ('Bright', 20),
#  ('Uncle', 20),
#  ('Woods', 20),
#  ('Untold', 20),
#  ('Border', 20),
#  ('Style', 20),
#  ('Musical', 20),
#  ('3D', 20),
#  ('Words', 20),
#  ('French', 19),
#  ('Scarlet', 19),
#  ('Radio', 19),
#  ('Village', 19),
#  ('Damned', 19),
#  ('Runner', 19),
#  ('Monkey', 19),
#  ('Modern', 19),
#  ('Bank', 19),
#  ('Factory', 19),
#  ('Fog', 19),
#  ('Angry', 19),
#  ('Genius', 19),
#  ('Female', 19),
#  ('Hollow', 19),
#  ('Reunion', 19),
#  ('Me,', 19),
#  ('Food', 19),
#  ('Alley', 19),
#  ('Chinese', 19),
#  ('Burn', 19),
#  ('Jesse', 19),
#  ('Plan', 19),
#  ('Outer', 19),
#  ('Shoes', 19),
#  ('Peter', 19),
#  ('Kong', 19),
#  ('Academy', 19),
#  ('Beneath', 19),
#  ('Dick', 19),
#  ('Invasion', 19),
#  ('Daddy', 19),
#  ('Bachelor', 19),
#  ('Rainbow', 19),
#  ('Movie:', 19),
#  ('Key', 19),
#  ('Fighting', 19),
#  ('Together', 19),
#  ('Diamond', 19),
#  ('Wave', 19),
#  ('Chan', 19),
#  ('Claus', 19),
#  ('Darling', 19),
#  ('Hunters', 19),
#  ('Memory', 19),
#  ('Tour', 19),
#  ('vs', 19),
#  ('Twelve', 18),
#  ('Crossing', 18),
#  ('County', 18),
#  ('Taxi', 18),
#  ('Siege', 18),
#  ('Drive', 18),
#  ('Lightning', 18),
#  ('Much', 18),
#  ('Savage', 18),
#  ('Trial', 18),
#  ('League', 18),
#  ('Bye', 18),
#  ('Fine', 18),
#  ('Thin', 18),
#  ('Venus', 18),
#  ('Sunset', 18),
#  ('Farm', 18),
#  ('Honeymoon', 18),
#  ('Fairy', 18),
#  ('Bell', 18),
#  ('Gay', 18),
#  ('Incredible', 18),
#  ('Sugar', 18),
#  ('Desire', 18),
#  ('Strikes', 18),
#  ('Sons', 18),
#  ('Birds', 18),
#  ('Mirror', 18),
#  ('Chase', 18),
#  ('Step', 18),
#  ('Innocent', 18),
#  ('Playing', 18),
#  ('Dollar', 18),
#  ('Hole', 18),
#  ('Wicked', 18),
#  ('Keep', 18),
#  ('Elephant', 18),
#  ('Rabbit', 18),
#  ('Seduction', 18),
#  ('Dolls', 18),
#  ('Ladies', 18),
#  ('Universe', 18),
#  ('Widow', 18),
#  ('Moving', 18),
#  ('Teen', 18),
#  ('30', 18),
#  ('Lie', 18),
#  ('Parade', 18),
#  ('Violent', 18),
#  ('Un', 18),
#  ('Lane', 18),
#  ('Zatôichi', 18),
#  ('Letters', 18),
#  ('Satan', 18),
#  ('del', 18),
#  ('Tower', 18),
#  ('Las', 17),
#  ('Courage', 17),
#  ...]
